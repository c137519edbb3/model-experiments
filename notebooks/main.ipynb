# %%
#!/usr/bin/env python3
"""
Test script to demonstrate the video segment parsing functions.
"""
import sys
import os

# For Jupyter: manually set the path to your project root or utils directory
sys.path.append(os.path.abspath("../"))

from src.utils.parse import parse_video_segments, parse_video_segments_simple

file_path = "../data/mask_UCFCrime_Test.txt"

print("Testing parse_video_segments_simple function:")
print("=" * 50)

# Test the grouped parsing function
grouped_results = parse_video_segments(file_path)

print(f"Total videos found: {len(grouped_results)}")
print("\nFirst 3 videos:")
for i, video_data in enumerate(grouped_results[:3]):
    print(f"\nVideo {i+1}:")
    print(video_data)
    print("-" * 30)
# Out:
# Testing parse_video_segments_simple function:
# ...
# Total videos found: 310
#
# First 3 videos:
#
# Video 1:
# Video: Abuse037_x264
# 00:01.2 - 00:08.2 :- A white car with double flashes slowly appeared on the screen, crushing the black dog walking in the middle of the road.
# 00:08.4 - 00:25.3 :- The white car was driving in the middle of the road, and several dogs ran onto the road.
# 00:25.3 - 00:48.5 :-  There was a black dog left on the road. It walked to the middle of the road next to the dog that had just been crushed.
# 00:40.4 - 00:47.6 :- The gray dog pulled out the tail of the dog that had just been run over by the car, then stayed for a few minutes and left.
# 00:48.5 - 00:59.1 :- The black dog walked away and left the middle of the road
# ------------------------------
#
# Video 2:
# Video: Abuse038_x264
# ...
